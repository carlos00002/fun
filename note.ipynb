# %%
import pandas as pd

# %%
df  = pd.read_csv("fake_car_loan_data.csv")

# %%
df.sample(2)
# Out:
#         customer_id  annual_income vehicle_make vehicle_model  vehicle_year  \
# 32255  CUST00032256       71342.64        Buick     Encore GX          2022
# 80075  CUST00080076       68064.22        Buick         Regal          2022
#
#        loan_amount  initial_apr  current_apr  loan_term_months  \
# 32255     56684.37        10.38        13.26                84
# 80075     51750.85         8.78         9.27                84
#
#        autopay_enrolled  num_successful_payments  credit_score  \
# 32255             False                       37           649
# 80075             False                       31           651
#
#       loan_start_date loan_end_date loan_status
# 32255      2025-10-31    2032-09-24        Late
# 80075      2022-12-01    2029-10-25     Current

# %%
df.loan_status.value_counts()
# Out:
# loan_status
# Current        56452
# Late           13045
# Paid Off       12708
# Delinquent      6908
# Default         4353
# Charged Off     4306
# Settled         2228
# Name: count, dtype: int64

# %%
keep = ['Default','Paid Off']

# %%
final = df.query("loan_status in @keep")

# %%
import numpy as np
final['target'] = np.where(final['loan_status'] == 'Default', 1,0)
# Out:
# /tmp/ipykernel_6488/1930542362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['target'] = np.where(final['loan_status'] == 'Default', 1,0)

# %%
final.sample(4)
# Out:
#         customer_id  annual_income vehicle_make vehicle_model  vehicle_year  \
# 97560  CUST00097561       63677.12          GMC     Hummer EV          2023
# 2936   CUST00002937       55888.43          GMC        Acadia          2024
# 23389  CUST00023390       39445.62        Buick       Enclave          2023
# 75518  CUST00075519       85259.70     Cadillac      Celestiq          2022
#
#        loan_amount  initial_apr  current_apr  loan_term_months  \
# 97560     38731.86        13.91        14.99                84
# 2936      27315.71        14.38        13.67                84
# 23389     23453.27        12.52        12.16                48
# 75518     45993.65         4.75         6.26                48
#
#        autopay_enrolled  num_successful_payments  credit_score  \
# 97560              True                       30           643
# 2936               True                       24           541
# 23389              True                       29           609
# 75518             False                       40           727
#
#       loan_start_date loan_end_date loan_status  target
# 97560      2025-06-18    2032-05-12    Paid Off       0
# 2936       2025-03-25    2032-02-17     Default       1
# 23389      2024-01-25    2028-01-04    Paid Off       0
# 75518      2023-03-07    2027-02-14    Paid Off       0

# %%
final.to_csv("loan_ready_ml.csv")
